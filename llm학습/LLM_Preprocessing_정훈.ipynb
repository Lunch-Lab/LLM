# %%
#file_path="/Users/ijeonghun/Documents/github/crawling_data/data/user_review_filtered.xlsx"
file_path="3_naver_user_크롤링_user_df_지선.xlsx"
from pandas import read_excel
file=read_excel(file_path)

# %%
from konlpy.tag import Kkma

# %%
file.dropna(axis=0)["긍정/부정"].value_counts()
# Out:
# 긍정/부정
# 긍정    386
# 부정     58
# 중립     45
# Name: count, dtype: int64

# %%
use_sample=file.dropna(axis=0)

# %%
use_sample
# Out:
#     user_name     place_name place_cate      place_loc use_method wait_time  \
# 0     giblihi         오봉집 석촌         한식  서울특별시 송파구 송파동      포장·배달     바로 입장
# 1     giblihi            교차점        돈가스  서울특별시 송파구 석촌동      예약 없이     바로 입장
# 2     giblihi           현대마트      슈퍼,마트  서울특별시 송파구 석촌동       정보없음      정보없음
# 3     giblihi        에이라운드헤어        미용실  서울특별시 송파구 석촌동       정보없음      정보없음
# 4     giblihi      써브웨이 석촌역점       샌드위치  서울특별시 송파구 송파동      포장·배달     바로 입장
# ..        ...            ...        ...            ...        ...       ...
# 487    리뷰KING    로스터리 락온 선릉점     카페,디저트  서울특별시 강남구 삼성동      예약 없이     바로 입장
# 488    리뷰KING  파리바게뜨 풍무꿈에그린점       베이커리    경기도 김포시 풍무동      예약 없이     바로 입장
# 489    리뷰KING          한성돈까스        돈가스  서울특별시 서초구 잠원동      예약 없이     바로 입장
# 490    리뷰KING      죠샌드위치 선릉점       샌드위치  서울특별시 강남구 삼성동      예약 없이     바로 입장
# 491    리뷰KING           비바커피     카페,디저트  서울특별시 강남구 삼성동      예약 없이     바로 입장
#
# ...

# %%
kkma=Kkma()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 kkma=Kkma()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/konlpy/tag/_kkma.py:44, in Kkma.__init__(self, jvmpath, max_heap_size)
#      42 def __init__(self, jvmpath=None, max_heap_size=1024):
#      43     if not jpype.isJVMStarted():
# ---> 44         jvm.init_jvm(jvmpath, max_heap_size)
#      46     kkmaJavaPackage = jpype.JPackage('kr.lucypark.kkma')
#      47     KkmaInterfaceJavaClass = kkmaJavaPackage.KkmaInterface
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/konlpy/jvm.py:64, in init_jvm(jvmpath, max_heap_size)
#      61     jvmpath = '%s/lib/jli/libjli.dylib' % jvmpath.split('/lib/')[0]
#      63 if jvmpath:
# ---> 64     jpype.startJVM(jvmpath, '-Dfile.encoding=UTF8',
# ...
